# %%
# The NLTK book assumes we import these each time
import nltk, re, pprint
from nltk import word_tokenize
from IPython.display import Image

# %% [markdown]
# Examples from the NLTK book: using regex's to find patterns from a wordlist

# %%
wordlist = [w for w in nltk.corpus.words.words('en') if w.islower()]

# %%
[w for w in wordlist if re.search('ed$', w)]
# Out:
# [u'abaissed',
#  u'abandoned',
#  u'abased',
#  u'abashed',
#  u'abatised',
#  u'abed',
#  u'aborted',
#  u'abridged',
#  u'abscessed',
#  u'absconded',
#  u'absorbed',
#  u'abstracted',
#  u'abstricted',
#  u'accelerated',
#  u'accepted',
#  u'accidented',
#  u'accoladed',
#  u'accolated',
#  u'accomplished',
#  u'accosted',
#  u'accredited',
#  u'accursed',
#  u'accused',
#  u'accustomed',
#  u'acetated',
#  u'acheweed',
#  u'aciculated',
#  u'aciliated',
#  u'acknowledged',
#  u'acorned',
#  u'acquainted',
#  u'acquired',
#  u'acquisited',
#  u'acred',
#  u'aculeated',
#  u'addebted',
#  u'added',
#  u'addicted',
#  u'addlebrained',
#  u'addleheaded',
#  u'addlepated',
#  u'addorsed',
#  u'adempted',
#  u'adfected',
#  u'adjoined',
#  u'admired',
#  u'admitted',
#  u'adnexed',
#  u'adopted',
#  u'adossed',
#  u'adreamed',
#  u'adscripted',
#  u'aduncated',
#  u'advanced',
#  u'advised',
#  u'aeried',
#  u'aethered',
#  u'afeared',
#  u'affected',
#  u'affectioned',
#  u'affined',
#  u'afflicted',
#  u'affricated',
#  u'affrighted',
#  u'affronted',
#  u'aforenamed',
#  u'afterfeed',
#  u'aftershafted',
#  u'afterthoughted',
#  u'afterwitted',
#  u'agazed',
#  u'aged',
#  u'agglomerated',
#  u'aggrieved',
#  u'agminated',
#  u'agnamed',
#  u'agonied',
#  u'agreed',
#  u'agueweed',
#  u'ahungered',
#  u'aiguilletted',
#  u'ailweed',
#  u'airbrained',
#  u'airified',
#  u'aiseweed',
#  u'aisled',
#  u'alarmed',
#  u'alated',
#  u'alimonied',
#  u'aliped',
#  u'alleyed',
#  u'allied',
#  u'alligatored',
#  u'allseed',
#  u'almsdeed',
#  u'aloed',
#  u'altared',
#  u'alveolated',
#  u'amazed',
#  u'ameed',
#  u'amiced',
#  u'amphitheatered',
#  u'ampullated',
#  u'amused',
#  u'anchored',
#  u'angled',
#  u'anguiped',
#  u'anguished',
#  u'angulated',
#  u'angulinerved',
#  u'anhungered',
#  u'animated',
#  u'aniseed',
#  u'annodated',
#  u'annulated',
#  u'anomaliped',
#  u'anserated',
#  u'anteflected',
#  u'anteflexed',
#  u'antimoniated',
#  u'antimoniureted',
#  u'antimoniuretted',
#  u'antiquated',
#  u'antired',
#  u'antiweed',
#  u'antlered',
#  u'apertured',
#  u'apexed',
#  u'apicifixed',
#  u'apiculated',
#  u'apocopated',
#  u'apostrophied',
#  u'appearanced',
#  u'appellatived',
#  u'appendaged',
#  u'appendiculated',
#  u'applied',
#  u'appressed',
#  u'aralkylated',
#  u'arbored',
#  u'arched',
#  u'architraved',
#  u'arcked',
#  u'arcuated',
#  u'ared',
#  u'areolated',
#  u'ariled',
#  u'arillated',
#  u'armchaired',
#  u'armed',
#  u'armied',
#  u'armillated',
#  u'armored',
#  u'armoried',
#  u'arpeggiated',
#  u'arpeggioed',
#  u'arrased',
#  u'arrowed',
#  u'arrowheaded',
#  u'arrowweed',
#  u'arseneted',
#  u'arsenetted',
#  u'arseniureted',
#  u'articled',
#  u'articulated',
#  u'ashamed',
#  u'ashlared',
#  u'ashweed',
#  u'aspersed',
#  u'asphyxied',
#  u'assented',
#  u'assessed',
#  u'assigned',
#  u'assistanted',
#  u'associated',
#  u'assonanced',
#  u'assorted',
#  u'assumed',
#  u'assured',
#  u'asteriated',
#  u'astonied',
#  u'aswooned',
#  u'atrophiated',
#  u'atrophied',
#  u'attached',
#  u'attired',
#  u'attrited',
#  u'augmented',
#  u'aurated',
#  u'auricled',
#  u'auriculated',
#  u'authorized',
#  u'autoinhibited',
#  u'autosensitized',
#  u'autosled',
#  u'averted',
#  u'avowed',
#  u'awearied',
#  u'awned',
#  u'awninged',
#  u'axed',
#  u'axhammered',
#  u'axised',
#  u'axled',
#  u'axseed',
#  u'axweed',
#  u'azoted',
#  u'azured',
#  u'babied',
#  u'babished',
#  u'babyfied',
#  u'baccated',
#  u'backboned',
#  u'backed',
#  u'backhanded',
#  u'backwatered',
#  u'baconweed',
#  u'badgerweed',
#  u'bagged',
#  u'bagwigged',
#  u'baked',
#  u'balanced',
#  u'balconied',
#  u'baldachined',
#  u'baldricked',
#  u'balled',
#  u'ballweed',
#  u'balsamweed',
#  u'balustered',
#  u'balustraded',
#  u'bandannaed',
#  u'banded',
#  u'bandoleered',
#  u'bangled',
#  u'banked',
#  u'bankweed',
#  u'bannered',
#  u'barbated',
#  u'barbed',
#  u'barebacked',
#  u'bareboned',
#  u'barefaced',
#  u'barefooted',
#  u'barehanded',
#  u'bareheaded',
#  u'barelegged',
#  u'barenecked',
#  u'barmybrained',
#  u'barred',
#  u'barreled',
#  u'bartizaned',
#  u'basebred',
#  u'based',
#  u'basehearted',
#  u'basifixed',
#  u'basilweed',
#  u'basined',
#  u'basinerved',
#  u'basqued',
#  u'bastioned',
#  u'bated',
#  u'bathroomed',
#  u'battered',
#  u'batteried',
#  u'battled',
#  u'battlemented',
#  u'bayed',
#  u'bayoneted',
#  u'beached',
#  u'beaded',
#  u'beaked',
#  u'bealtared',
#  u'beamed',
#  u'beanweed',
#  u'beaproned',
#  u'bearded',
#  u'beautied',
#  u'beavered',
#  u'beballed',
#  u'bebannered',
#  u'bebed',
#  u'bebelted',
#  u'bebled',
#  u'bebothered',
#  u'bebouldered',
#  u'bebuttoned',
#  u'becassocked',
#  u'bechained',
#  u'bechignoned',
#  u'becircled',
#  u'becoiffed',
#  u'becombed',
#  u'becousined',
#  u'becrinolined',
#  u'becuffed',
#  u'becurtained',
#  u'becushioned',
#  u'bed',
#  u'bedaggered',
#  u'bedangled',
#  u'bedded',
#  u'bediademed',
#  u'bediamonded',
#  u'beedged',
#  u'beefheaded',
#  u'beeheaded',
#  u'beeswinged',
#  u'beetled',
#  u'beetleheaded',
#  u'beetleweed',
#  u'beeweed',
#  u'befamilied',
#  u'befanned',
#  u'befathered',
#  u'beferned',
#  u'befetished',
#  u'befezzed',
#  u'befilleted',
#  u'befilmed',
#  u'beforested',
#  u'befountained',
#  u'befrocked',
#  u'befrogged',
#  u'befurbelowed',
#  u'befurred',
#  u'begabled',
#  u'begarlanded',
#  u'begartered',
#  u'beggarweed',
#  u'beglobed',
#  u'begoggled',
#  u'begowned',
#  u'behatted',
#  u'behaviored',
#  u'beheadlined',
#  u'behooped',
#  u'beinked',
#  u'bekilted',
#  u'beknived',
#  u'beknotted',
#  u'belaced',
#  u'belated',
#  u'belatticed',
#  u'belavendered',
#  u'beledgered',
#  u'belfried',
#  u'beliked',
#  u'belimousined',
#  u'belled',
#  u'bellied',
#  u'bellmouthed',
#  u'bellweed',
#  u'beloved',
#  u'belozenged',
#  u'belted',
#  u'bemazed',
#  u'bemedaled',
#  u'bemedalled',
#  u'bemitered',
#  u'bemitred',
#  u'bemused',
#  u'bemuslined',
#  u'bended',
#  u'beneaped',
#  u'beneficed',
#  u'beneighbored',
#  u'benempted',
#  u'benighted',
#  u'bennetweed',
#  u'benumbed',
#  u'benweed',
#  u'benzoated',
#  u'benzoinated',
#  u'bepastured',
#  u'bepatched',
#  u'beperiwigged',
#  u'bepewed',
#  u'bepillared',
#  u'bepistoled',
#  u'beplaided',
#  u'beplumed',
#  u'beribanded',
#  u'beribboned',
#  u'beringed',
#  u'beringleted',
#  u'berobed',
#  u'berouged',
#  u'berried',
#  u'berthed',
#  u'beruffed',
#  u'beruffled',
#  u'beshawled',
#  u'besieged',
#  u'beslushed',
#  u'besotted',
#  u'bespecked',
#  u'bespectacled',
#  u'besped',
#  u'bespeed',
#  u'bespelled',
#  u'bespurred',
#  u'bestatued',
#  u'bestayed',
#  u'bestrapped',
#  u'bestubbled',
#  u'besweatered',
#  u'betattered',
#  u'betaxed',
#  u'betowered',
#  u'betrothed',
#  u'betrousered',
#  u'betted',
#  u'betuckered',
#  u'beturbaned',
#  u'betusked',
#  u'betutored',
#  u'betwattled',
#  u'beuniformed',
#  u'beveled',
#  u'bevelled',
#  u'bevesseled',
#  u'bevesselled',
#  u'bevined',
#  u'bevoiled',
#  u'bewaitered',
#  u'bewhiskered',
#  u'bewigged',
#  u'bewildered',
#  u'bewinged',
#  u'bewired',
#  u'bewrathed',
#  u'biangulated',
#  u'biarcuated',
#  u'biarticulated',
#  u'bicarbureted',
#  u'biciliated',
#  u'bicolored',
#  u'bicorned',
#  u'bidented',
#  u'bifanged',
#  u'bifidated',
#  u'biflected',
#  u'biforked',
#  u'biformed',
#  u'bifronted',
#  u'bifurcated',
#  u'bigeminated',
#  u'bighearted',
#  u'bigmouthed',
#  u'bigoted',
#  u'bigwigged',
#  u'bilamellated',
#  u'bilaminated',
#  u'billed',
#  u'bilobated',
#  u'bilobed',
#  u'bilsted',
#  u'bimaculated',
#  u'bimotored',
#  u'bindweed',
#  u'bineweed',
#  u'binominated',
#  u'binucleated',
#  u'biparted',
#  u'bipectinated',
#  u'biped',
#  u'bipennated',
#  u'bipinnated',
#  u'bipinnatiparted',
#  u'bipinnatisected',
#  u'biradiated',
#  u'birdmouthed',
#  u'birdseed',
#  u'birdweed',
#  u'birostrated',
#  u'birthbed',
#  u'bisexed',
#  u'bishopweed',
#  u'bistered',
#  u'bistipuled',
#  u'bisubstituted',
#  u'bitted',
#  u'bitterhearted',
#  u'bitterweed',
#  u'bituberculated',
#  u'bitumed',
#  u'bivalved',
#  u'bivaulted',
#  u'bivocalized',
#  u'blackhearted',
#  u'blackseed',
#  u'blackshirted',
#  u'bladderseed',
#  u'bladderweed',
#  u'bladed',
#  u'blakeberyed',
#  u'blamed',
#  u'blanked',
#  u'blanketed',
#  u'blanketweed',
#  u'blasted',
#  u'bleached',
#  u'bleared',
#  u'bleed',
#  u'blended',
#  u'blessed',
#  u'blighted',
#  u'blinded',
#  u'blindfolded',
#  u'blindweed',
#  u'blinked',
#  u'blinkered',
#  u'blistered',
#  u'blisterweed',
#  u'blithehearted',
#  u'bloated',
#  u'blobbed',
#  u'blocked',
#  u'blockheaded',
#  u'blooded',
#  u'bloodied',
#  u'bloodshed',
#  u'bloodstained',
#  u'bloodweed',
#  u'blossomed',
#  u'blotched',
#  u'bloused',
#  u'blowzed',
#  u'bludgeoned',
#  u'bluebelled',
#  u'bluehearted',
#  u'blueweed',
#  u'blunderheaded',
#  u'blunthearted',
#  u'blurred',
#  u'bobbed',
#  u'bobsled',
#  u'bobtailed',
#  u'bodiced',
#  u'bodied',
#  u'boiled',
#  u'boldhearted',
#  u'bolectioned',
#  u'boled',
#  u'boleweed',
#  u'bolled',
#  u'bombed',
#  u'bonded',
#  u'boned',
#  u'boneheaded',
#  u'bonneted',
#  u'booked',
#  u'booted',
#  u'bootied',
#  u'boozed',
#  u'bordered',
#  u'bordured',
#  u'bosomed',
#  u'bossed',
#  u'bosselated',
#  u'botched',
#  u'botherheaded',
#  u'bothsided',
#  u'bottled',
#  u'bottomed',
#  u'boughed',
#  u'bounded',
#  u'bountied',
#  u'bowed',
#  u'boweled',
#  u'bowlegged',
#  u'bowstringed',
#  u'braced',
#  u'braceleted',
#  u'brackened',
#  u'bracted',
#  u'braided',
#  u'brambled',
#  u'branched',
#  u'branded',
#  u'brandied',
#  u'brangled',
#  u'bravehearted',
#  u'brawned',
#  u'brazenfaced',
#  u'breasted',
#  u'breastweed',
#  u'breathed',
#  u'brecciated',
#  u'bred',
#  u'breeched',
#  u'breed',
#  u'breviped',
#  u'bridebed',
#  u'brideweed',
#  u'bridged',
#  u'bridled',
#  u'briered',
#  u'brimmed',
#  u'bristled',
#  u'broadhearted',
#  u'brocaded',
#  u'brocked',
#  u'brokenhearted',
#  u'bromoiodized',
#  u'bronzed',
#  u'brooked',
#  u'brookweed',
#  u'broomweed',
#  u'broozled',
#  u'browed',
#  u'brownweed',
#  u'bruckled',
#  u'brushed',
#  u'buboed',
#  u'bucked',
#  u'buckled',
#  u'buckskinned',
#  u'buffed',
#  u'bugled',
#  u'bugleweed',
#  u'bugseed',
#  u'bugweed',
#  u'bulbed',
#  u'bulked',
#  u'bulkheaded',
#  u'bullated',
#  u'bulldogged',
#  u'bulleted',
#  u'bulletheaded',
#  u'bullheaded',
#  u'bullweed',
#  u'bummed',
#  u'bundlerooted',
#  u'bundweed',
#  u'bunted',
#  u'buried',
#  u'burled',
#  u'burned',
#  u'burnoosed',
#  u'burntweed',
#  u'burred',
#  u'burroweed',
#  u'burseed',
#  u'burweed',
#  u'bushed',
#  u'busied',
#  u'busked',
#  u'buskined',
#  u'busted',
#  u'bustled',
#  u'busybodied',
#  u'buttered',
#  u'butterfingered',
#  u'butterweed',
#  u'butteryfingered',
#  u'buttocked',
#  u'buttoned',
#  u'buttonweed',
#  u'cabled',
#  u'caboshed',
#  u'caddiced',
#  u'caddised',
#  u'cadenced',
#  u'cadweed',
#  u'caftaned',
#  u'caged',
#  u'cairned',
#  u'caissoned',
#  u'calced',
#  u'calcified',
#  u'calcined',
#  u'calculated',
#  u'calibered',
#  u'calicoed',
#  u'caligated',
#  u'calpacked',
#  u'calved',
#  u'calycled',
#  u'calyculated',
#  u'camailed',
#  u'camerated',
#  u'cammed',
#  u'campanulated',
#  u'campshed',
#  u'camused',
#  u'canaliculated',
#  u'cancellated',
#  u'cancered',
#  u'cancerweed',
#  u'candied',
#  u'candlelighted',
#  u'candlesticked',
#  u'candyweed',
#  u'canioned',
#  u'cankered',
#  u'cankerweed',
#  u'canned',
#  u'cannelated',
#  u'cannelured',
#  u'cannoned',
#  u'cannulated',
#  u'canted',
#  u'cantilevered',
#  u'cantoned',
#  u'cantred',
#  u'caped',
#  u'capernoited',
#  u'capeweed',
#  u'capitaled',
#  u'capitated',
#  u'capped',
#  u'capriped',
#  u'capsulated',
#  u'capuched',
#  u'carapaced',
#  u'carbolated',
#  u'carboyed',
#  u'carbuncled',
#  u'carcaneted',
#  u'carded',
#  u'carinated',
#  u'carkled',
#  u'carnaged',
#  u'carnationed',
#  u'carpetweed',
#  u'carried',
#  u'carrotweed',
#  u'carucated',
#  u'carunculated',
#  u'cased',
#  u'casemated',
#  u'casemented',
#  u'caseweed',
#  u'casqued',
#  u'castellated',
#  u'castled',
#  u'castorized',
#  u'catamited',
#  u'cataracted',
#  u'catarrhed',
#  u'catchweed',
#  u'catenated',
#  u'caterpillared',
#  u'catfaced',
#  u'catfooted',
#  u'cathedraled',
#  u'caudated',
#  u'caverned',
#  u'cavitied',
#  u'cayenned',
#  u'cedared',
#  u'ceilinged',
#  u'celebrated',
#  u'cellated',
#  u'celled',
#  u'cellulated',
#  u'celluloided',
#  u'centered',
#  u'centriffed',
#  u'centuried',
#  u'cerated',
#  u'cered',
#  u'certified',
#  u'chafeweed',
#  u'chaffseed',
#  u'chaffweed',
#  u'chafted',
#  u'chained',
#  u'chaliced',
#  u'chambered',
#  u'chamberleted',
#  u'chamberletted',
#  u'chanceled',
#  u'channeled',
#  u'channelled',
#  u'chaped',
#  u'chapleted',
#  u'chapournetted',
#  u'chapped',
#  u'charioted',
#  u'charqued',
#  u'chartered',
#  u'chasmed',
#  u'chasteweed',
#  u'chasubled',
#  u'checked',
#  u'checkered',
#  u'checkrowed',
#  u'cheered',
#  u'cheliped',
#  u'cherried',
#  u'chickenbreasted',
#  u'chickenhearted',
#  u'chickenweed',
#  u'chickweed',
#  u'chicqued',
#  u'chiggerweed',
#  u'chignoned',
#  u'childbed',
#  u'childed',
#  u'chilled',
#  u'chined',
#  u'chinned',
#  u'chipped',
#  u'chiseled',
#  u'chitinized',
#  u'chokered',
#  u'chokeweed',
#  u'cholterheaded',
#  u'chopped',
#  u'choppered',
#  u'chorded',
#  u'chowderheaded',
#  u'christened',
#  u'chubbed',
#  u'chuckleheaded',
#  u'churchified',
#  u'churled',
#  u'ciliated',
#  u'cingulated',
#  u'cinnamoned',
#  u'cinquefoiled',
#  u'circled',
#  u'circumscribed',
#  u'circumstanced',
#  u'cirrated',
#  u'cirrhosed',
#  u'cirriped',
#  u'cisted',
#  u'citied',
#  u'citified',
#  u'citrated',
#  u'civilized',
#  u'clammed',
#  u'clammyweed',
#  u'clanned',
#  u'clapped',
#  u'classed',
#  u'classified',
#  u'clavated',
#  u'clavellated',
#  u'clawed',
#  u'claybrained',
#  u'clayweed',
#  u'cleaded',
#  u'cleanhanded',
#  u'cleanhearted',
#  u'clearheaded',
#  u'clearhearted',
#  u'clearweed',
#  u'cled',
#  u'cleeked',
#  u'clefted',
#  u'clerestoried',
#  u'cliented',
#  u'cliffed',
#  u'cliffweed',
#  u'clipped',
#  u'cloaked',
#  u'clocked',
#  u'clodpated',
#  u'cloistered',
#  u'closed',
#  u'closefisted',
#  u'closehanded',
#  u'closehearted',
#  u'closemouthed',
#  u'clotweed',
#  u'clouded',
#  u'clouted',
#  u'clovered',
#  u'clubbed',
#  u'clubfisted',
#  u'clubfooted',
#  u'clubweed',
#  u'clustered',
#  u'coaged',
#  u'coaggregated',
#  u'coated',
#  u'coattailed',
#  u'cobbed',
#  u'cocashweed',
#  u'cochleated',
#  u'cockaded',
#  u'cocked',
#  u'cockeyed',
#  u'cockled',
#  u'cockneybred',
#  u'cockscombed',
#  u'cockweed',
#  u'codheaded',
#  u'coed',
#  u'coelongated',
#  u'coembedded',
#  u'coequated',
#  u'coexpanded',
#  u'coffeeweed',
#  u'cogged',
#  u'coifed',
#  u'coiled',
#  u'coldhearted',
#  u'coleseed',
#  u'colicweed',
#  u'collared',
#  u'collected',
#  u'collied',
#  u'colloped',
#  u'colonnaded',
#  u'colored',
#  u'columnated',
#  u'columned',
#  u'combed',
#  u'combined',
#  u'compacted',
#  u'complected',
#  u'complexioned',
#  u'complicated',
#  u'componed',
#  u'componented',
#  u'composed',
#  u'compressed',
#  u'comprised',
#  u'compulsed',
#  u'conamed',
#  u'concamerated',
#  u'concealed',
#  u'conceded',
#  u'conceited',
#  u'concentrated',
#  u'concerned',
#  u'concerted',
#  u'conched',
#  u'conchyliated',
#  u'condemned',
#  u'condensed',
#  u'conditioned',
#  u'conduplicated',
#  u'coned',
#  u'confated',
#  u'conferted',
#  u'confined',
#  u'confirmed',
#  u'conflated',
#  u'confounded',
#  u'confused',
#  u'congested',
#  u'conjoined',
#  u'conjugated',
#  u'connected',
#  u'conred',
#  u'consecrated',
#  u'considered',
#  u'consolidated',
#  u'constrained',
#  u'constricted',
#  u'consumpted',
#  u'contagioned',
#  u'contented',
#  u'contextured',
#  u'continued',
#  u'contorted',
#  u'contortioned',
#  u'contracted',
#  u'contractured',
#  u'contusioned',
#  u'converted',
#  u'convexed',
#  u'convinced',
#  u'convoluted',
#  u'coolheaded',
#  u'coolweed',
#  u'copied',
#  u'copleased',
#  u'copped',
#  u'coppernosed',
#  u'copperytailed',
#  u'coppiced',
#  u'coppled',
#  u'copsewooded',
#  u'copygraphed',
#  u'coraled',
#  u'corded',
#  u'corduroyed',
#  u'cored',
#  u'coreflexed',
#  u'corked',
#  u'cornered',
#  u'cornified',
#  u'cornuated',
#  u'cornuted',
#  u'corollated',
#  u'coronaled',
#  u'coronated',
#  u'coroneted',
#  u'coronetted',
#  u'corpusculated',
#  u'corrected',
#  u'correlated',
#  u'corridored',
#  ...]

# %%
[w for w in wordlist if re.search('^..j..t..$', w)]
# Out:
# [u'abjectly',
#  u'adjuster',
#  u'dejected',
#  u'dejectly',
#  u'injector',
#  u'majestic',
#  u'objectee',
#  u'objector',
#  u'rejecter',
#  u'rejector',
#  u'unjilted',
#  u'unjolted',
#  u'unjustly']

# %% [markdown]
# **Exercise: look at a crossword puzzle like the one below.  Mentally remove some of the filled in letters and search for words that only match some of the remaining letters.  See how well the regex does at generating a list containing the correct word. **

# %%
Image(url='http://2.bp.blogspot.com/-Z9EdELyjmOY/VSSQuSN0qRI/AAAAAAAAY4U/crxW-Bz9cnM/s1600/Apr8%2Bcopy.jpg', width=300)
# Out:
# <img src="http://2.bp.blogspot.com/-Z9EdELyjmOY/VSSQuSN0qRI/AAAAAAAAY4U/crxW-Bz9cnM/s1600/Apr8%2Bcopy.jpg" width="300"/>

# %%
[w for w in wordlist if re.search('^ast..$', w)]
# Out:
# [u'astay', u'aster', u'astir', u'astor']

# %% [markdown]
# Find the words that can be construed from keying in 4653 from a keypad

# %%
Image(url='http://www.nltk.org/images/T9.png', width=200)
# Out:
# <img src="http://www.nltk.org/images/T9.png" width="200"/>

# %%
[w for w in wordlist if re.search('^[ghi][jlk][mno][wxyz]$', w)]
# Out:
# [u'glow', u'gloy']

# %% [markdown]
# **Exercise: finds words that fit the last four digits of your phone number**

# %%
[w for w in wordlist if re.search('^[mno][mno][tuv]$', w)]
# Out:
# [u'mot', u'mou', u'not']
